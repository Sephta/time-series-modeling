# %% [markdown]
# # Visual Playground

# %% [markdown]
# ### Importing Stats Module

# %%
import stats_and_vis as sv

# %% [markdown]
# ## Plot Time Series

# %% [markdown]
# #### Plotting one Time Series

# %%
sv.plot_ts(sv.ts1)
# Out:
# [28.3,
#  26.6,
#  25.3,
#  24.2,
#  23.7,
#  23.4,
#  23.2,
#  22.8,
#  22.7,
#  22.5,
#  22.2,
#  22.0,
#  21.9,
#  21.9,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.5,
#  21.4,
#  21.3,
#  21.2,
#  21.1,
#  21.0,
#  20.9,
#  20.8,
#  20.8,
#  20.7,
#  20.7,
#  20.6,
#  20.5,
#  20.4,
#  20.3,
#  20.2,
#  20.2,
#  20.4,
#  20.2,
#  20.1,
#  19.9,
#  19.7,
#  19.5,
#  19.3,
#  19.4,
#  19.3,
#  19.2,
#  19.0,
#  18.8,
#  18.7,
#  18.6,
#  18.5,
#  18.4,
#  18.2,
#  18.1,
#  17.9,
#  17.7,
#  17.5,
#  17.4,
#  17.4,
#  17.4,
#  17.0,
#  17.2,
#  17.1,
#  17.1,
#  16.9,
#  16.8,
#  16.8,
#  16.7,
#  16.7,
#  16.9,
#  17.0,
#  17.3,
#  17.2,
#  17.1,
#  17.1,
#  17.0,
#  17.0,
#  17.4,
#  18.0,
#  18.4,
#  18.9,
#  18.8,
#  18.7,
#  18.7,
#  19.0,
#  19.2,
#  19.3,
#  19.7,
#  19.5,
#  20.0,
#  20.1,
#  20.2,
#  20.8,
#  21.2,
#  21.6,
#  21.7,
#  21.9,
#  22.0,
#  23.4,
#  22.7,
#  23.2,
#  23.7,
#  23.9,
#  23.9,
#  24.3,
#  24.5,
#  24.6,
#  25.2,
#  25.1,
#  25.2,
#  25.8,
#  25.8,
# ...

# %% [markdown]
# #### Plotting multiple Time Series

# %%
sv.plot_ts([sv.ts1, sv.ts2, sv.ts3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ccbd93919621> in <module>
# ----> 1 sv.plot_ts([ts1, ts2, ts3])
#
# NameError: name 'ts1' is not defined

# %% [markdown]
# ## Histogram Plot

# %% [markdown]
# ##### Note: Right Vertical joint graph is the Histogram

# %%
sv.histogram(sv.ts1)

# %% [markdown]
# ## Box and Whiskers Plot

# %% [markdown]
# #### 5-number summary is printed first

# %%
sv.box_plot(sv.ts1)
# Out:
# Min: 16.7
# Max: 28.6
# SD: 3.712
# Mean: 21.973
# Median: 21.2

# %% [markdown]
# ## Plotting & Computing Normality

# %% [markdown]
# #### Currently performs 3 of the Normality tests (Shapiro, Kolmogorov, & Anderson)
# #### to get a consensus of the Time Series. (Still tweaking with it)

# %%
sv.normality_test(sv.ts1)
# Out:
# Shapiro-Wilk Statistic Test Result: 0.921
# P-value: 3.974246567395312e-07: Null Hypothesis Rejected. Not from normal distribution.
#
# Kolmogorov-Smirnov Statistic Test Result: 66.418
# P-value: 3.780575026015663e-15Null Hypothesis Rejected. Not from normal distribution.
#
# Anderson-Darling Statistic Test Result: 3.389430767055501
# 15.000: 0.561: Rejected. Data not normal
# 10.000: 0.639: Rejected. Data not normal
# 5.000: 0.766: Rejected. Data not normal
# 2.500: 0.894: Rejected. Data not normal
# 1.000: 1.064: Rejected. Data not normal

# %% [markdown]
# ## Computing Errors

# %% [markdown]
# ### Compute MSE

# %%
sv.mse(sv.ts1, sv.ts1_pred)
# Out:
# Mean Square Error: 8.11

# %% [markdown]
# ### Compute MAPE

# %%
sv.mape(sv.ts1, sv.ts1_pred)
# Out:
# Mean Absolute Precentage Error: 4.31

# %% [markdown]
# ### Compute SMAPE

# %%
sv.smape(sv.ts1, sv.ts1_pred)
# Out:
# Symmetric Mean Absolute Precentage Error: 2.37
